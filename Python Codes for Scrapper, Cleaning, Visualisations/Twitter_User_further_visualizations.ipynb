# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\Veenadharini\Downloads\twitter_user.csv')
df.head()
# Out:
#    Unnamed: 0      User_ID          Name  Followers Location  \
# 0           0      CORSAIR       CORSAIR    1660036      USA
# 1           1  primegaming  Prime Gaming     578811       IN
# 2           2   Complexity    Complexity     292522       TX
# 3           3   ScufGaming          SCUF    1480792       GA
# 4           4          MLG           MLG    1872999       NY
#
#                                          Description  \
# 0  The leading source for PC components and gamin...
# 1  Official for all things Prime Gaming. Grab fre...
# 2  ✭ Esports, gaming, and culture ✭ Part of the @...
# 3  Change your game. We created the performance c...
# 4                    Watch the best in esports live.
#
#                   Created_At  Verified                      URL  Total_Tweets  \
# 0  2009-03-25 21:41:25+00:00      True  https://t.co/KGJpZKjIz0         22160
# 1  2016-07-29 14:06:30+00:00      True  https://t.co/HjomKwsE8a          9795
# ...

# %%
print(df.corr())
# Out:
#                             Unnamed: 0  Followers  Verified  Total_Tweets  \
# Unnamed: 0                    1.000000  -0.322222 -0.133562     -0.203468
# Followers                    -0.322222   1.000000  0.302598      0.532482
# Verified                     -0.133562   0.302598  1.000000      0.399271
# Total_Tweets                 -0.203468   0.532482  0.399271      1.000000
# Total_tweets_in_last_24hrs    0.327178   0.099099  0.170437      0.406254
# Following                     0.112013   0.284301  0.321771      0.633391
# Total_Likes_By_Profile       -0.008512   0.297809  0.333135      0.607279
#
#                             Total_tweets_in_last_24hrs  Following  \
# Unnamed: 0                                    0.327178   0.112013
# Followers                                     0.099099   0.284301
# Verified                                      0.170437   0.321771
# Total_Tweets                                  0.406254   0.633391
# ...

# %%
sns.displot(df['Followers'])

# %%
sns.set(rc={'figure.figsize':(500,25)})
sns.relplot(data=df, x ="User_ID",y ="Total_Likes_By_Profile", hue ="Total_Tweets")

# %%
sns.pairplot(df)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
